# %% [markdown]
# <a href="https://colab.research.google.com/github/aqshal36/Pengantar-Data-Science/blob/main/tugas_sesi_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/MyDrive/Phyton/tugas sesi 3/Data Tugas Tuton STDA4101-2024.2.xlsx')
df.head()
# Out:
#      Y  AGE    LDL  HDL  TCH     LTG  GLU  Unnamed: 7  Unnamed: 8  \
# 0  128   53  143.8   58  4.0  5.0499   91         NaN         NaN
# 1  102   53  115.2   67  3.0  4.3041  100         NaN         NaN
# 2  302   23  131.4   65  3.0  4.5850   91         NaN         NaN
# 3  198   65  160.6   40  5.0  4.5218   84         NaN         NaN
# 4   95   41  104.4   56  3.0  3.9703   76         NaN         NaN
#
#                                      Unnamed: 9
# 0  Y,  perkembangan penyakit setelah satu tahun
# 1                       AGE, usia (dalam tahun)
# 2                 LDL, low-density lipoproteins
# 3                HDL, high-density lipoproteins
# 4                  TCH, total cholesterol / HDL
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# ...

# %%
mean_Y = df['Y'].mean()
median_Y = df['Y'].median()
modus_Y = df['Y'].mode()[0]
range_Y = df['Y'].max() - df['Y'].min()
variance_Y = df['Y'].var()
std_dev_Y = df['Y'].std()
skewness_Y = df['Y'].skew()
kurtosis_Y = df['Y'].kurtosis()


mean_usia = df['AGE'].mean()
median_usia = df['AGE'].median()
modus_usia = df['AGE'].mode()[0]
range_usia = df['AGE'].max() - df['AGE'].min()
variance_usia = df['AGE'].var()
std_dev_usia = df['AGE'].std()
skewness_usia = df['AGE'].skew()
kurtosis_usia = df['AGE'].kurtosis()

mean_low_density_lipoproteins = df['LDL'].mean()
median_low_density_lipoproteins = df['LDL'].median()
modus_low_density_lipoproteins = df['LDL'].mode()[0]
range_low_density_lipoproteins = df['LDL'].max() - df['LDL'].min()
variance_low_density_lipoproteins = df['LDL'].var()
std_dev_low_density_lipoproteins = df['LDL'].std()
skewness_low_density_lipoproteins = df['LDL'].skew()
kurtosis_low_density_lipoproteins = df['LDL'].kurtosis()

mean_high_density_lipoproteins = df['HDL'].mean()
median_high_density_lipoproteins = df['HDL'].median()
modus_high_density_lipoproteins = df['HDL'].mode()[0]
range_high_density_lipoproteins = df['HDL'].max() - df['HDL'].min()
variance_high_density_lipoproteins = df['HDL'].var()
std_dev_high_density_lipoproteins = df['HDL'].std()
skewness_high_density_lipoproteins = df['HDL'].skew()
kurtosis_high_density_lipoproteins = df['HDL'].kurtosis()

mean_total_cholesterol = df['TCH'].mean()
median_total_cholesterol = df['TCH'].median()
modus_total_cholesterol = df['TCH'].mode()[0]
range_total_cholesterol = df['TCH'].max() - df['TCH'].min()
variance_total_cholesterol = df['TCH'].var()
std_dev_total_cholesterol = df['TCH'].std()
skewness_total_cholesterol = df['TCH'].skew()
kurtosis_total_cholesterol = df['TCH'].kurtosis()

mean_triglycerides = df['LTG'].mean()
median_triglycerides = df['LTG'].median()
modus_triglycerides = df['LTG'].mode()[0]
range_triglycerides = df['LTG'].max() - df['LTG'].min()
variance_triglycerides = df['LTG'].var()
std_dev_triglycerides = df['LTG'].std()
skewness_triglycerides = df['LTG'].skew()
kurtosis_triglycerides = df['LTG'].kurtosis()

mean_blood_SUGAR = df['GLU'].mean()
median_blood_SUGAR = df['GLU'].median()
modus_blood_SUGAR = df['GLU'].mode()[0]
range_blood_SUGAR = df['GLU'].max() - df['GLU'].min()
variance_blood_SUGAR = df['GLU'].var()
std_dev_blood_SUGAR = df['GLU'].std()
skewness_blood_SUGAR = df['GLU'].skew()
kurtosis_blood_SUGAR = df['GLU'].kurtosis()


print("perkembangan penyakit setelah satu tahun - mean", mean_Y)
print("perkembangan penyakit setelah satu tahun - median", median_Y)
print("perkembangan penyakit setelah satu tahun - modus", modus_Y)
print("perkembangan penyakit setelah satu tahun - rane", range_Y)
print("perkembangan penyakit setelah satu tahun - variance", variance_Y)
print("perkembangan penyakit setelah satu tahun - standard deviation", std_dev_Y)
print("perkembangan penyakit setelah satu tahun - skewness", skewness_Y)
print("perkembangan penyakit setelah satu tahun - kurtosis", kurtosis_Y)

print("mean usia (dalam tahun) - mean:", mean_usia)
print("median usia (dalam tahun) - median:", median_usia)
print("modus usia (dalam tahun) - modus:", modus_usia)
print("range usia (dalam tahun) - range:", range_usia)
print("variance usia (dalam tahun) - variance:", variance_usia)
print("standard deviation usia (dalam tahun) - standard deviation:", std_dev_usia)
print("skewness usia (dalam tahun) - skewness:", skewness_usia)
print("kurtosis usia (dalam tahun) - kurtosis:", kurtosis_usia)

print("mean low-density lipoproteins - mean:", mean_low_density_lipoproteins)
print("median low-density lipoproteins - median:", median_low_density_lipoproteins)
print("modus low-density lipoproteins - modus:", modus_low_density_lipoproteins)
print("range low-density lipoproteins - range:", range_low_density_lipoproteins)
print("variance low-density lipoproteins - variance:", variance_low_density_lipoproteins)
print("standard deviation low-density lipoproteins - standard deviation:", std_dev_low_density_lipoproteins)
print("skewness low-density lipoproteins - skewness:", skewness_low_density_lipoproteins)
print("kurtosis low-density lipoproteins - kurtosis:", kurtosis_low_density_lipoproteins)

print("mean high-density lipoproteins - mean:", mean_high_density_lipoproteins)
print("median high-density lipoproteins - median:", median_high_density_lipoproteins)
print("modus high-density lipoproteins - modus:", modus_high_density_lipoproteins)
print("range high-density lipoproteins - range:", range_high_density_lipoproteins)
print("variance high-density lipoproteins - variance:", variance_high_density_lipoproteins)
print("standard deviation high-density lipoproteins - standard deviation:", std_dev_high_density_lipoproteins)
print("skewness high-density lipoproteins - skewness:", skewness_high_density_lipoproteins)

print("mean total cholesterol - mean:", mean_total_cholesterol)
print("median total cholesterol - median:", median_total_cholesterol)
print("modus total cholesterol - modus:", modus_total_cholesterol)
print("range total cholesterol - range:", range_total_cholesterol)
print("variance total cholesterol - variance:", variance_total_cholesterol)
print("standard deviation total cholesterol - standard deviation:", std_dev_total_cholesterol)
print("skewness total cholesterol - skewness:", skewness_total_cholesterol)
print("kurtosis total cholesterol - kurtosis:", kurtosis_total_cholesterol)

print("mean triglycerides - mean:", mean_triglycerides)
print("median triglycerides - median:", median_triglycerides)
print("modus triglycerides - modus:", modus_triglycerides)
print("range triglycerides - range:", range_triglycerides)
print("variance triglycerides - variance:", variance_triglycerides)
print("standard deviation triglycerides - standard deviation:", std_dev_triglycerides)
print("skewness triglycerides - skewness:", skewness_triglycerides)
print("kurtosis triglycerides - kurtosis:", kurtosis_triglycerides)

print("mean blood sugar - mean:", mean_blood_SUGAR)
print("median blood sugar - median:", median_blood_SUGAR)
print("modus blood sugar - modus:", modus_blood_SUGAR)
print("range blood sugar - range:", range_blood_SUGAR)
print("variance blood sugar - variance:", variance_blood_SUGAR)
print("standard deviation blood sugar - standard deviation:", std_dev_blood_SUGAR)
print("skewness blood sugar - skewness:", skewness_blood_SUGAR)
print("kurtosis blood sugar - kurtosis:", kurtosis_blood_SUGAR)
# Out:
# perkembangan penyakit setelah satu tahun - mean 160.22
# perkembangan penyakit setelah satu tahun - median 141.5
# perkembangan penyakit setelah satu tahun - modus 53
# perkembangan penyakit setelah satu tahun - rane 311
# perkembangan penyakit setelah satu tahun - variance 6057.587474747473
# perkembangan penyakit setelah satu tahun - standard deviation 77.83050478281297
# perkembangan penyakit setelah satu tahun - skewness 0.46689789438940754
# perkembangan penyakit setelah satu tahun - kurtosis -0.9331677790773267
# mean usia (dalam tahun) - mean: 47.43
# median usia (dalam tahun) - median: 49.5
# modus usia (dalam tahun) - modus: 53
# range usia (dalam tahun) - range: 46
# variance usia (dalam tahun) - variance: 153.96474747474744
# standard deviation usia (dalam tahun) - standard deviation: 12.408253199977322
# skewness usia (dalam tahun) - skewness: -0.3639907857432946
# kurtosis usia (dalam tahun) - kurtosis: -0.9071877971658706
# mean low-density lipoproteins - mean: 118.588
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Y'], bins=15, kde=True, color='skyblue', edgecolor='black')

# Tambahkan garis Mean, Median, dan Modus
plt.axvline(mean_Y, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_Y:.2f}')
plt.axvline(median_Y, color='green', linestyle='--', linewidth=2, label=f'Median: {median_Y}')
plt.axvline(modus_Y, color='blue', linestyle='--', linewidth=2, label=f'Modus: {modus_Y}')

# Judul dan label
plt.title('Distribusi Variabel Y (Perkembangan Penyakit Setelah Satu Tahun)', fontsize=14)
plt.xlabel('Nilai Y')
plt.ylabel('Frekuensi')
plt.legend()
plt.grid(True)
plt.show()

# %%
print("Symmetry (Kesimetrisan)\nNilai mean (160.22) lebih besar dari median (141.5) dan modus (53), yang menunjukkan data miring ke kanan (positive skew).\n\nSkewness (Kemencengan):\nNilai skewness = 0.467 menunjukkan distribusi miring ke kanan, namun tidak ekstrem. Data memiliki kemiringan sedang.\n\nKurtosis:\nNilai kurtosis = -0.933 berarti distribusi cenderung platikurtik — yaitu, lebih \"datar\" dibanding distribusi normal (memiliki puncak yang lebih rendah dan sebaran lebih lebar).\n\nKesimpulan bentuk distribusi:\n\nDistribusi variabel Y asimetris ke kanan (miring positif),\n\nMenunjukkan adanya beberapa pasien dengan nilai perkembangan penyakit yang jauh lebih tinggi dari mayoritas,\n\nDistribusi tidak terlalu tajam (platikurtik).")
#The code below was not causing a syntax error, so no changes were made.
#Skewness (Kemencengan):
#Nilai skewness = 0.467 menunjukkan distribusi miring ke kanan, namun tidak ekstrem. Data memiliki kemiringan sedang.

#Kurtosis:
#Nilai kurtosis = -0.933 berarti distribusi cenderung platikurtik — yaitu, lebih "datar" dibanding distribusi normal (memiliki puncak yang lebih rendah dan sebaran lebih lebar).

#Kesimpulan bentuk distribusi:

#Distribusi variabel Y asimetris ke kanan (miring positif),

#Menunjukkan adanya beberapa pasien dengan nilai perkembangan penyakit yang jauh lebih tinggi dari mayoritas,

#Distribusi tidak terlalu tajam (platikurtik).
# Out:
# Symmetry (Kesimetrisan)
# Nilai mean (160.22) lebih besar dari median (141.5) dan modus (53), yang menunjukkan data miring ke kanan (positive skew).
#
# Skewness (Kemencengan):
# Nilai skewness = 0.467 menunjukkan distribusi miring ke kanan, namun tidak ekstrem. Data memiliki kemiringan sedang.
#
# Kurtosis:
# Nilai kurtosis = -0.933 berarti distribusi cenderung platikurtik — yaitu, lebih "datar" dibanding distribusi normal (memiliki puncak yang lebih rendah dan sebaran lebih lebar).
#
# Kesimpulan bentuk distribusi:
#
# Distribusi variabel Y asimetris ke kanan (miring positif),
#
# Menunjukkan adanya beberapa pasien dengan nilai perkembangan penyakit yang jauh lebih tinggi dari mayoritas,
#
# Distribusi tidak terlalu tajam (platikurtik).

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Y'], color='lightblue', width=0.3)
plt.title("Box Plot Variabel Y: Perkembangan Penyakit Setelah Satu Tahun")
plt.ylabel("Nilai Y")
plt.grid(True)
plt.show()
